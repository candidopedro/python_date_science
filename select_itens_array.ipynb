# %%
import numpy as np

# %%
a = np.array([[1,2,3,4],[5,6,8,9]])
print(a)
# Out:
# [[1 2 3 4]
#  [5 6 8 9]]

# %%
a[0,2] # <- Array [row, column]
# Out:
# np.int64(3)

# %%
a [0, :] # ':' -> Vai até o último item
# Out:
# array([1, 2, 3, 4])

# %%
a[:, 1] # ':' -> mostra tudo que tem na coluna 1
# Out:
# array([2, 6])
