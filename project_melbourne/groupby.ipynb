# %%
import pandas as pd
import re

# %%
df = pd.read_csv('../data_base/house.csv')
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='str')

# %%
df.groupby(['SellerG']).sum().sort_values('Price', ascending= False).head(10)[['Price', 'Rooms', 'Distance', 'Postcode']] # Seleciona a coluna de vendedores 'SellerG' e organiza de forma decressente do preço, selecionando apenas os 10 primeiro - Retornando apenas as coluna -> 'Price', 'Rooms', 'Distance', 'Postcode'
# Out:
#                       Price  Rooms  Distance  Postcode
# SellerG
# Jellis         5.301902e+09  16948   47831.6  17116422
# Nelson         4.089097e+09  13808   34410.5  14489179
# Barry          4.022899e+09  22919  108662.2  21405391
# Marshall       3.337732e+09   9437   20141.4   8949613
# hockingstuart  3.174822e+09  12635   53918.3  13571171
# Buxton         3.103258e+09  10707   48190.6  10669223
# Ray            2.953669e+09  14961   76239.1  14329293
# Fletchers      1.384292e+09   5402   21963.2   5039345
# Biggin         1.002292e+09   4203   12250.2   4783284
# Noel           9.618405e+08   3447   14386.3   3328766
